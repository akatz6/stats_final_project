# %%
import pandas as pd
from tabulate import tabulate
# reading csv files

# %%
colnames =[
"state",
"county",
"community",
"communityname",
"fold",
"population",
"householdsize",
"racepctblack",
"racePctWhite",
"racePctAsian",
"racePctHisp",
"agePct12t21",
"agePct12t29",
"agePct16t24",
"agePct65up",
"numbUrban",
"pctUrban",
"medIncome",
"pctWWage",
"pctWFarmSelf",
"pctWInvInc",
"pctWSocSec",
"pctWPubAsst",
"pctWRetire",
"medFamInc",
"perCapInc",
"whitePerCap",
"blackPerCap",
"indianPerCap",
"AsianPerCap",
"OtherPerCap",
"HispPerCap",
"NumUnderPov",
"PctPopUnderPov",
"PctLess9thGrade",
"PctNotHSGrad",
"PctBSorMore",
"PctUnemployed",
"PctEmploy",
"PctEmplManu",
"PctEmplProfServ",
"PctOccupManu",
"PctOccupMgmtProf",
"MalePctDivorce",
"MalePctNevMarr",
"FemalePctDiv",
"TotalPctDiv",
"PersPerFam",
"PctFam2Par",
"PctKids2Par",
"PctYoungKids2Par",
"PctTeen2Par",
"PctWorkMomYoungKids",
"PctWorkMom",
"NumIlleg",
"PctIlleg",
"NumImmig",
"PctImmigRecent",
"PctImmigRec5",
"PctImmigRec8",
"PctImmigRec10",
"PctRecentImmig",
"PctRecImmig5",
"PctRecImmig8",
"PctRecImmig10",
"PctSpeakEnglOnly",
"PctNotSpeakEnglWell",
"PctLargHouseFam",
"PctLargHouseOccup",
"PersPerOccupHous",
"PersPerOwnOccHous",
"PersPerRentOccHous",
"PctPersOwnOccup",
"PctPersDenseHous",
"PctHousLess3BR",
"MedNumBR",
"HousVacant",
"PctHousOccup",
"PctHousOwnOcc",
"PctVacantBoarded",
"PctVacMore6Mos",
"MedYrHousBuilt",
"PctHousNoPhone",
"PctWOFullPlumb",
"OwnOccLowQuart",
"OwnOccMedVal",
"OwnOccHiQuart",
"RentLowQ",
"RentMedian",
"RentHighQ",
"MedRent",
"MedRentPctHousInc",
"MedOwnCostPctInc",
"MedOwnCostPctIncNoMtg",
"NumInShelters",
"NumStreet",
"PctForeignBorn",
"PctBornSameState",
"PctSameHouse85",
"PctSameCity85",
"PctSameState85",
"LemasSwornFT",
"LemasSwFTPerPop",
"LemasSwFTFieldOps",
"LemasSwFTFieldPerPop",
"LemasTotalReq",
"LemasTotReqPerPop",
"PolicReqPerOffic",
"PolicPerPop",
"RacialMatchCommPol",
"PctPolicWhite",
"PctPolicBlack",
"PctPolicHisp",
"PctPolicAsian",
"PctPolicMinor",
"OfficAssgnDrugUnits",
"NumKindsDrugsSeiz",
"PolicAveOTWorked",
"LandArea",
"PopDens",
"PctUsePubTrans",
"PolicCars",
"PolicOperBudg",
"LemasPctPolicOnPatr",
"LemasGangUnitDeploy",
"LemasPctOfficDrugUn",
"PolicBudgPerPop",
"ViolentCrimesPerPop",
]

# %% [markdown]
# columns we should keep
#
# [
# "communityname",
# "population",
# "householdsize",
# "agePct12t21",
# "agePct12t29",
# "agePct16t24",
# "agePct65up",
# "medIncome",
# "pctWWage",
# "pctWFarmSelf",
# "pctWInvInc",
# "pctWSocSec",
# "pctWPubAsst",
# "pctWRetire",
# "medFamInc",
# "perCapInc",
# "NumUnderPov",
# "PctPopUnderPov",
# "PctLess9thGrade",
# "PctNotHSGrad",
# "PctBSorMore",
# "PctUnemployed",
# "PctEmploy",
# "PctEmplManu",
# "PctEmplProfServ",
# "PctOccupManu",
# "PctOccupMgmtProf",
# "MalePctDivorce",
# "MalePctNevMarr",
# "FemalePctDiv",
# "TotalPctDiv",
# "PersPerFam",
# "PctFam2Par",
# "PctKids2Par",
# "PctYoungKids2Par",
# "PctTeen2Par",
# "PctWorkMomYoungKids",
# "PctWorkMom",
# "NumIlleg",
# "PctIlleg",
# "NumImmig",
# "PctImmigRecent",
# "PctImmigRec5",
# "PctImmigRec8",
# "PctImmigRec10",
# "PctRecentImmig",
# "PctRecImmig5",
# "PctRecImmig8",
# "PctRecImmig10",
# "PctSpeakEnglOnly",
# "PctNotSpeakEnglWell",
# "PctLargHouseFam",
# "PctLargHouseOccup",
# "PersPerOccupHous",
# "PersPerOwnOccHous",
# "PersPerRentOccHous",
# "PctPersOwnOccup",
# "PctPersDenseHous",
# "PctHousLess3BR",
# "MedNumBR",
# "HousVacant",
# "PctHousOccup",
# "PctHousOwnOcc",
# "PctVacantBoarded",
# "PctVacMore6Mos",
# "MedYrHousBuilt",
# "PctHousNoPhone",
# "PctWOFullPlumb",
# "OwnOccLowQuart",
# "OwnOccMedVal",
# "OwnOccHiQuart",
# "RentLowQ",
# "RentMedian",
# "RentHighQ",
# "MedRent",
# "MedRentPctHousInc",
# "MedOwnCostPctInc",
# "MedOwnCostPctIncNoMtg",
# "NumInShelters",
# "PctForeignBorn",
# "PctBornSameState",
# "LemasSwornFT",
# "LemasSwFTPerPop",
# "LemasSwFTFieldOps",
# "LemasSwFTFieldPerPop",
# "LemasTotalReq",
# "LemasTotReqPerPop",
# "PolicReqPerOffic",
# "PolicPerPop",
# "RacialMatchCommPol",
# "OfficAssgnDrugUnits",
# "NumKindsDrugsSeiz",
# "PolicAveOTWorked",
# "PopDens",
# "PolicCars",
# "PolicOperBudg",
# "LemasPctPolicOnPatr",
# "LemasGangUnitDeploy",
# "LemasPctOfficDrugUn",
# "PolicBudgPerPop",
# "ViolentCrimesPerPop",
# ]

# %%
data =  pd.read_csv('communities.data', names=colnames, header=None)
print(len(data))
data.replace("?", pd.NA, inplace=True)
data.dropna(axis=1, inplace=True)
# Out:
# 1994

# %%
print(data.columns.tolist())
# Out:
# ['state', 'communityname', 'fold', 'population', 'householdsize', 'racepctblack', 'racePctWhite', 'racePctAsian', 'racePctHisp', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'numbUrban', 'pctUrban', 'medIncome', 'pctWWage', 'pctWFarmSelf', 'pctWInvInc', 'pctWSocSec', 'pctWPubAsst', 'pctWRetire', 'medFamInc', 'perCapInc', 'whitePerCap', 'blackPerCap', 'indianPerCap', 'AsianPerCap', 'HispPerCap', 'NumUnderPov', 'PctPopUnderPov', 'PctLess9thGrade', 'PctNotHSGrad', 'PctBSorMore', 'PctUnemployed', 'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'PctOccupManu', 'PctOccupMgmtProf', 'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv', 'TotalPctDiv', 'PersPerFam', 'PctFam2Par', 'PctKids2Par', 'PctYoungKids2Par', 'PctTeen2Par', 'PctWorkMomYoungKids', 'PctWorkMom', 'NumIlleg', 'PctIlleg', 'NumImmig', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PctRecentImmig', 'PctRecImmig5', 'PctRecImmig8', 'PctRecImmig10', 'PctSpeakEnglOnly', 'PctNotSpeakEnglWell', 'PctLarg
# ...

# %%
columns_of_interest = ["medIncome", 
                       "ViolentCrimesPerPop", 
                       "population", 
                       "pctWPubAsst", 
                       "pctWRetire", 
                       "householdsize", 
                       "PctUnemployed", 
                       "PctWorkMomYoungKids", 
                       "PctNotSpeakEnglWell",
                       "HousVacant",
                       "PctVacMore6Mos",
                       "PctWOFullPlumb",
                       "MedRent",
                       "NumStreet",
                       "PopDens",
                       ]

data = data[columns_of_interest]


data_sort = data.sort_values('ViolentCrimesPerPop')
least_crime_100 = data_sort.head(10)
print(tabulate(data_sort.head(10), headers='keys', tablefmt='pretty'))
print(tabulate(data_sort.tail(10), headers='keys', tablefmt='pretty'))
# Out:
# +------+-----------+---------------------+------------+-------------+------------+---------------+---------------+---------------------+---------------------+------------+----------------+----------------+---------+-----------+---------+
# |      | medIncome | ViolentCrimesPerPop | population | pctWPubAsst | pctWRetire | householdsize | PctUnemployed | PctWorkMomYoungKids | PctNotSpeakEnglWell | HousVacant | PctVacMore6Mos | PctWOFullPlumb | MedRent | NumStreet | PopDens |
# +------+-----------+---------------------+------------+-------------+------------+---------------+---------------+---------------------+---------------------+------------+----------------+----------------+---------+-----------+---------+
# |  83  |    0.4    |         0.0         |    0.01    |     0.2     |    0.8     |     0.52      |     0.23      |         0.4         |        0.03         |    0.0     |      0.68      |      0.09      |  0.25   |    0.0    |  0.05   |
# ...

# %%
safest_100 = data_sort.head(100)
unsafest_100 = data_sort.tail(100)


# look for regression model linear regression model
# statistical models python

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np
violent_crimes = safest_100["ViolentCrimesPerPop"]
print(violent_crimes.head())
print(violent_crimes.tail())
data_violent = data["ViolentCrimesPerPop"]
print(data_violent.head())
print(data_violent.tail())

mu, std = norm.fit(violent_crimes)

x = np.linspace(0, .03, 100)
p = norm.pdf(x, mu, std)
p_data = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
plt.plot(x, p_data, 'k', linewidth=2)
plt.hist(violent_crimes, bins=5,  alpha=0.7, color='blue', edgecolor='black')
plt.hist(data_violent, bins=5,  alpha=0.7, color='blue', edgecolor='black')
plt.xlabel('Violent Crimes')
plt.ylabel('Frequency')
plt.title('Violent Crimes')

# Show the plot
plt.show()
# Out:
# 83      0.0
# 1230    0.0
# 1462    0.0
# 773     0.0
# 1656    0.0
# Name: ViolentCrimesPerPop, dtype: float64
# 796     0.02
# 800     0.02
# 1761    0.02
# 194     0.02
# 1708    0.02
# Name: ViolentCrimesPerPop, dtype: float64
# 0    0.20
# 1    0.67
# 2    0.43
# 3    0.12
# 4    0.03
# Name: ViolentCrimesPerPop, dtype: float64
# 1989    0.09
# 1990    0.45
# 1991    0.23
# 1992    0.19
# 1993    0.48
# Name: ViolentCrimesPerPop, dtype: float64

# %%
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#histogram

def histogram(item, str):
  plt.hist(item, bins=20, color='blue', edgecolor='black')
  plt.title(f'{str} Histogram')
  plt.xlabel(str)
  plt.ylabel('Frequency')
  plt.show()

# %%
#scatter plot

def scatter(x_axis, y_axis, x_str, y_str):
  len(x_axis)
  len(y_axis)
  plt.scatter(x_axis, y_axis, alpha=0.5, color='blue')
  plt.title(f'Scatter Plot between {x_str} and {y_str}')
  plt.xlabel(x_str)
  plt.ylabel(y_str)
  plt.show()

# %%
violence  = safest_100["ViolentCrimesPerPop"]
histogram(violence, "Violence per 100,000 people")

# %%
pctWPubAsst = safest_100["pctWPubAsst"]
histogram(pctWPubAsst, "Population on Public Assistance")
scatter(violence, pctWPubAsst, "Violence", "Population on Public Assistance")

#reject null hypothesis
stat, pval_no_chage = stats.ttest_ind(violence, pctWPubAsst)
print(pval_no_chage)
# Out:
# 1.5664417496455568e-23

# %%
medIncome = safest_100["medIncome"]
histogram(medIncome, "Median Income")
scatter(violence, medIncome, "Violence", "Median Income")
#reject null hypothesis
stat, pval_no_chage = stats.ttest_ind(violence, medIncome)
print(pval_no_chage)
# Out:
# 7.026390500712107e-54

# %%
population = safest_100["population"]
histogram(population, "Population")
scatter(violence, population, "Violence", "Population")
#reject null hypothesis
stat, pval_no_chage = stats.ttest_ind(violence, population)
print(pval_no_chage)
# Out:
# 0.07899206419562632

# %%
pctWRetire = safest_100["pctWRetire"]
histogram(pctWRetire, "Percent Retired")
scatter(violence, pctWRetire, "Violence", "Percent Retired")
#reject null hypothesis
stat, pval_no_chage = stats.ttest_ind(violence, pctWRetire)
print(pval_no_chage)
# Out:
# 4.076304180344116e-75

# %%
householdsize = safest_100["householdsize"]
histogram(householdsize, "House Hold Size")
scatter(violence, householdsize, "Violence", "House Hold Size")
#reject null hypothesis
stat, pval_no_chage = stats.ttest_ind(violence, householdsize)
print(pval_no_chage)
# Out:
# 1.7212874284677357e-88

# %%
PctUnemployed = safest_100["PctUnemployed"]
histogram(PctUnemployed, "Percent Unemployed")
scatter(violence, PctUnemployed, "Violence", "Percent Unemployed")
#reject null hypothesis
stat, pval_no_chage = stats.ttest_ind(violence, PctUnemployed)
print(pval_no_chage)
# Out:
# 3.033882402817256e-36

# %%
PctWorkMomYoungKids = safest_100["PctWorkMomYoungKids"]
histogram(PctWorkMomYoungKids, "Percent Working Moms With Young Kids")
scatter(violence, PctWorkMomYoungKids, "Violence", "Percent Working Moms With Young Kids")

#reject null hypothesis
stat, pval_no_chage = stats.ttest_ind(violence, PctWorkMomYoungKids)
print(pval_no_chage)
# Out:
# 9.864651402423239e-56

# %%
PctNotSpeakEnglWell = safest_100["PctNotSpeakEnglWell"]
histogram(PctNotSpeakEnglWell, "Percent Poor English Speaking Skills")
scatter(violence, PctNotSpeakEnglWell, "Violence", "Percent Poor English Speaking Skills")

#reject null hypothesis
stat, pval_no_chage = stats.ttest_ind(violence, PctNotSpeakEnglWell)
print(pval_no_chage)
# Out:
# 1.0445015806239234e-09

# %%
HousVacant = safest_100["HousVacant"]
histogram(HousVacant, "Houses Vacant")
scatter(violence, HousVacant, "Violence", "Houses Vacant")

#do not reject null hypothesis
stat, pval_no_chage = stats.ttest_ind(violence, HousVacant)
print(pval_no_chage)
# Out:
# 0.937551174688849

# %%
PctVacMore6Mos = safest_100["PctVacMore6Mos"]
histogram(PctVacMore6Mos, "Houses Vacant For Six Months Or More")
scatter(violence, PctVacMore6Mos, "Violence", "Houses Vacant For Six Months Or More")

#reject null hypothesis
stat, pval_no_chage = stats.ttest_ind(violence, PctVacMore6Mos)
print(pval_no_chage)
# Out:
# 7.129755738720952e-72

# %%
PctWOFullPlumb = safest_100["PctWOFullPlumb"]
histogram(PctWOFullPlumb, "Percent With Full Plumbing")
scatter(violence, PctWOFullPlumb, "Violence", "Percent With Full Plumbing")

#reject null hypothesis
stat, pval_no_chage = stats.ttest_ind(violence, PctWOFullPlumb)
print(pval_no_chage)
# Out:
# 1.777957110883287e-27

# %%
MedRent = safest_100["MedRent"]
histogram(MedRent, "Median Rent")
scatter(violence, MedRent, "Violence", "Median Rent")

#reject null hypothesis
stat, pval_no_chage = stats.ttest_ind(violence, MedRent)
print(pval_no_chage)
# Out:
# 1.9518252884091816e-45

# %%
NumStreet = safest_100["NumStreet"]
histogram(NumStreet, "Number Of Homeless On Street")
scatter(violence, NumStreet, "Violence", "Number Of Homeless On Street")

#reject null hypothesis
stat, pval_no_chage = stats.ttest_ind(violence, NumStreet)
print(pval_no_chage)
# Out:
# 2.3541337503634422e-46

# %%
PopDens = safest_100["PopDens"]
histogram(PopDens, "Population Density")
scatter(violence, PopDens, "Violence", "Population Density")

#reject null hypothesis
stat, pval_no_chage = stats.ttest_ind(violence, PopDens)
print(pval_no_chage)
# Out:
# 1.4273773237361945e-16

# %%
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# medIncome + ViolentCrimesPerPop + population + pctWPubAsst + pctWRetire + householdsize + PctUnemployed + PctWorkMomYoungKids + PctNotSpeakEnglWell + HousVacant + PctVacMore6Mos + PctWOFullPlumb
fitd = smf.ols(formula='ViolentCrimesPerPop ~  MedRent + NumStreet + PopDens', data=safest_100).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.095
# Model:                             OLS   Adj. R-squared:                  0.067
# Method:                  Least Squares   F-statistic:                     3.362
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):             0.0219
# Time:                         11:10:06   Log-Likelihood:                 364.26
# No. Observations:                  100   AIC:                            -720.5
# Df Residuals:                       96   BIC:                            -710.1
# Df Model:                            3
# Covariance Type:             nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0115      0.002      7.176      0.000       0.008       0.015
# ...

# %%
fitd = smf.ols(formula='ViolentCrimesPerPop ~  MedRent + NumStreet + PopDens', data=data).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.240
# Model:                             OLS   Adj. R-squared:                  0.238
# Method:                  Least Squares   F-statistic:                     208.9
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):          8.41e-118
# Time:                         11:24:54   Log-Likelihood:                 348.94
# No. Observations:                 1994   AIC:                            -689.9
# Df Residuals:                     1990   BIC:                            -667.5
# Df Model:                            3
# Covariance Type:             nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2731      0.010     27.040      0.000       0.253       0.293
# ...

# %%
fitd = smf.ols(formula='ViolentCrimesPerPop ~  MedRent + NumStreet + PopDens', data=unsafest_100).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.075
# Model:                             OLS   Adj. R-squared:                  0.046
# Method:                  Least Squares   F-statistic:                     2.605
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):             0.0562
# Time:                         11:10:16   Log-Likelihood:                 106.51
# No. Observations:                  100   AIC:                            -205.0
# Df Residuals:                       96   BIC:                            -194.6
# Df Model:                            3
# Covariance Type:             nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9357      0.019     49.238      0.000       0.898       0.973
# ...

# %%
# householdsize + PctUnemployed + PctWorkMomYoungKids + PctNotSpeakEnglWell + HousVacant + PctVacMore6Mos + PctWOFullPlumb
fitd = smf.ols(formula='ViolentCrimesPerPop ~ medIncome + population + pctWPubAsst', data=safest_100).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.010
# Model:                             OLS   Adj. R-squared:                 -0.021
# Method:                  Least Squares   F-statistic:                    0.3292
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):              0.804
# Time:                         11:11:05   Log-Likelihood:                 359.78
# No. Observations:                  100   AIC:                            -711.6
# Df Residuals:                       96   BIC:                            -701.1
# Df Model:                            3
# Covariance Type:             nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0128      0.004      3.328      0.001       0.005       0.020
# ...

# %%
fitd = smf.ols(formula='ViolentCrimesPerPop ~  medIncome + population + pctWPubAsst', data=data).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.407
# Model:                             OLS   Adj. R-squared:                  0.407
# Method:                  Least Squares   F-statistic:                     456.2
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):          1.53e-225
# Time:                         11:25:30   Log-Likelihood:                 597.79
# No. Observations:                 1994   AIC:                            -1188.
# Df Residuals:                     1990   BIC:                            -1165.
# Df Model:                            3
# Covariance Type:             nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0892      0.016      5.630      0.000       0.058       0.120
# ...

# %%
fitd = smf.ols(formula='ViolentCrimesPerPop ~ medIncome + population + pctWPubAsst', data=unsafest_100).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.087
# Model:                             OLS   Adj. R-squared:                  0.059
# Method:                  Least Squares   F-statistic:                     3.061
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):             0.0318
# Time:                         11:12:19   Log-Likelihood:                 107.16
# No. Observations:                  100   AIC:                            -206.3
# Df Residuals:                       96   BIC:                            -195.9
# Df Model:                            3
# Covariance Type:             nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.8548      0.034     24.975      0.000       0.787       0.923
# ...

# %%
#  +  +  + PctNotSpeakEnglWell + HousVacant + PctVacMore6Mos + PctWOFullPlumb
fitd = smf.ols(formula='ViolentCrimesPerPop ~ householdsize + PctUnemployed + PctWorkMomYoungKids', data=safest_100).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.047
# Model:                             OLS   Adj. R-squared:                  0.017
# Method:                  Least Squares   F-statistic:                     1.561
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):              0.204
# Time:                         11:12:57   Log-Likelihood:                 361.65
# No. Observations:                  100   AIC:                            -715.3
# Df Residuals:                       96   BIC:                            -704.9
# Df Model:                            3
# Covariance Type:             nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.0213      0.003      6.345      0.000       0.015       0.028
# ...

# %%
fitd = smf.ols(formula='ViolentCrimesPerPop ~  householdsize + PctUnemployed + PctWorkMomYoungKids', data=data).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.270
# Model:                             OLS   Adj. R-squared:                  0.269
# Method:                  Least Squares   F-statistic:                     245.5
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):          1.62e-135
# Time:                         11:25:59   Log-Likelihood:                 389.88
# No. Observations:                 1994   AIC:                            -771.8
# Df Residuals:                     1990   BIC:                            -749.4
# Df Model:                            3
# Covariance Type:             nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.0325      0.023      1.396      0.163      -0.013       0.078
# ...

# %%
#  +  +  + PctNotSpeakEnglWell + HousVacant + PctVacMore6Mos + PctWOFullPlumb
fitd = smf.ols(formula='ViolentCrimesPerPop ~ householdsize + PctUnemployed + PctWorkMomYoungKids', data=unsafest_100).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.075
# Model:                             OLS   Adj. R-squared:                  0.046
# Method:                  Least Squares   F-statistic:                     2.596
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):             0.0568
# Time:                         11:13:06   Log-Likelihood:                 106.50
# No. Observations:                  100   AIC:                            -205.0
# Df Residuals:                       96   BIC:                            -194.6
# Df Model:                            3
# Covariance Type:             nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.8029      0.053     15.283      0.000       0.699       0.907
# ...

# %%
fitd = smf.ols(formula='ViolentCrimesPerPop ~ PctNotSpeakEnglWell + HousVacant + PctVacMore6Mos', data=safest_100).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.035
# Model:                             OLS   Adj. R-squared:                  0.005
# Method:                  Least Squares   F-statistic:                     1.150
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):              0.333
# Time:                         11:13:50   Log-Likelihood:                 361.03
# No. Observations:                  100   AIC:                            -714.1
# Df Residuals:                       96   BIC:                            -703.6
# Df Model:                            3
# Covariance Type:             nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.0118      0.002      5.345      0.000       0.007       0.016
# ...

# %%
fitd = smf.ols(formula='ViolentCrimesPerPop ~  PctNotSpeakEnglWell + HousVacant + PctVacMore6Mos', data=data).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.248
# Model:                             OLS   Adj. R-squared:                  0.247
# Method:                  Least Squares   F-statistic:                     219.0
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):          9.33e-123
# Time:                         11:26:25   Log-Likelihood:                 360.39
# No. Observations:                 1994   AIC:                            -712.8
# Df Residuals:                     1990   BIC:                            -690.4
# Df Model:                            3
# Covariance Type:             nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.1104      0.013      8.774      0.000       0.086       0.135
# ...

# %%
fitd = smf.ols(formula='ViolentCrimesPerPop ~  PctNotSpeakEnglWell + HousVacant + PctVacMore6Mos', data=unsafest_100).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.041
# Model:                             OLS   Adj. R-squared:                  0.011
# Method:                  Least Squares   F-statistic:                     1.362
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):              0.259
# Time:                         11:13:57   Log-Likelihood:                 104.68
# No. Observations:                  100   AIC:                            -201.4
# Df Residuals:                       96   BIC:                            -190.9
# Df Model:                            3
# Covariance Type:             nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.8573      0.031     27.786      0.000       0.796       0.919
# ...

# %%
fitd = smf.ols(formula='ViolentCrimesPerPop ~ NumStreet ', data=safest_100).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.046
# Model:                             OLS   Adj. R-squared:                  0.036
# Method:                  Least Squares   F-statistic:                     4.716
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):             0.0323
# Time:                         11:10:43   Log-Likelihood:                 361.61
# No. Observations:                  100   AIC:                            -719.2
# Df Residuals:                       98   BIC:                            -714.0
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0143      0.001     21.717      0.000       0.013       0.016
# ...

# %%
x = safest_100[['NumStreet']]
y_men = safest_100['ViolentCrimesPerPop']

x_train, x_test, y_men_train, y_men_test, = train_test_split(x, y_men, test_size = 0.3, 
                                                    random_state=42)

model_men = LinearRegression()
model_men.fit(x_train, y_men_train)


print("Intercept:", model_men.intercept_)
print("Coefficients:", model_men.coef_)
y_pred_men = model_men.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_men_test, y_pred_men)
print("Mean Squared Error:", mse)

print(f"The prediction equation is Violent Crime = {model_men.intercept_:.4f} + ({model_men.coef_[0]:.4f} * Homeless) + {mse:.4f}")
violent_Crime = model_men.intercept_ + (model_men.coef_[0] * 10) + mse
print(violent_Crime)

print("Does not work because of negative coef")
# Out:
# Intercept: 0.014782608695652174
# Coefficients: [-0.49275362]
# Mean Squared Error: 4.4322621298046634e-05
# The prediction equation is Violent Crime = 0.0148 + (-0.4928 * Homeless) + 0.0000
# -4.912709300567108

# %%
fitd = smf.ols(formula='ViolentCrimesPerPop ~  MedRent', data=unsafest_100).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.021
# Model:                             OLS   Adj. R-squared:                  0.011
# Method:                  Least Squares   F-statistic:                     2.117
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):              0.149
# Time:                         11:12:06   Log-Likelihood:                 103.66
# No. Observations:                  100   AIC:                            -203.3
# Df Residuals:                       98   BIC:                            -198.1
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9403      0.019     48.891      0.000       0.902       0.978
# ...

# %%
fitd = smf.ols(formula='ViolentCrimesPerPop ~ pctWPubAsst', data=unsafest_100).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.084
# Model:                             OLS   Adj. R-squared:                  0.075
# Method:                  Least Squares   F-statistic:                     9.014
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):            0.00340
# Time:                         11:12:42   Log-Likelihood:                 107.00
# No. Observations:                  100   AIC:                            -210.0
# Df Residuals:                       98   BIC:                            -204.8
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.8516      0.023     37.315      0.000       0.806       0.897
# ...

# %%
x = unsafest_100[['pctWPubAsst']]
y_men = unsafest_100['ViolentCrimesPerPop']

x_train, x_test, y_men_train, y_men_test, = train_test_split(x, y_men, test_size = 0.3, 
                                                    random_state=42)

model_men = LinearRegression()
model_men.fit(x_train, y_men_train)


print("Intercept:", model_men.intercept_)
print("Coefficients:", model_men.coef_)
y_pred_men = model_men.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_men_test, y_pred_men)
print("Mean Squared Error:", mse)

print(f"The prediction equation is Violent Crime = {model_men.intercept_:.4f} + ({model_men.coef_[0]:.4f} * Homeless) + {mse:.4f}")
violent_Crime = model_men.intercept_ + (model_men.coef_[0] * 1) + mse
print(violent_Crime)

print("Does Work")
# Out:
# Intercept: 0.8251799106100651
# Coefficients: [0.16152587]
# Mean Squared Error: 0.009909692578625848
# The prediction equation is Violent Crime = 0.8252 + (0.1615 * Homeless) + 0.0099
# 0.9966154685870686
# Does Work

# %%
fitd = smf.ols(formula='ViolentCrimesPerPop ~  PctUnemployed', data=unsafest_100).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.063
# Model:                             OLS   Adj. R-squared:                  0.054
# Method:                  Least Squares   F-statistic:                     6.637
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):             0.0115
# Time:                         11:14:56   Log-Likelihood:                 105.87
# No. Observations:                  100   AIC:                            -207.7
# Df Residuals:                       98   BIC:                            -202.5
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.8523      0.026     32.910      0.000       0.801       0.904
# ...

# %%
x = unsafest_100[['pctWPubAsst']]
y_men = unsafest_100['PctUnemployed']

x_train, x_test, y_men_train, y_men_test, = train_test_split(x, y_men, test_size = 0.3, 
                                                    random_state=42)

model_men = LinearRegression()
model_men.fit(x_train, y_men_train)


print("Intercept:", model_men.intercept_)
print("Coefficients:", model_men.coef_)
y_pred_men = model_men.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_men_test, y_pred_men)
print("Mean Squared Error:", mse)

print(f"The prediction equation is Violent Crime = {model_men.intercept_:.4f} + ({model_men.coef_[0]:.4f} * Homeless) + {mse:.4f}")
violent_Crime = model_men.intercept_ + (model_men.coef_[0] * 1) + mse
print(violent_Crime)

print("Does Work")
# Out:
# Intercept: 0.15228155870170396
# Coefficients: [0.72874216]
# Mean Squared Error: 0.015658222561836427
# The prediction equation is Violent Crime = 0.1523 + (0.7287 * Homeless) + 0.0157
# 0.8966819428740869
# Does Work

# %%
fitd = smf.ols(formula='ViolentCrimesPerPop ~  PctNotSpeakEnglWell + HousVacant', data=data).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.243
# Model:                             OLS   Adj. R-squared:                  0.243
# Method:                  Least Squares   F-statistic:                     320.4
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):          2.34e-121
# Time:                         11:27:06   Log-Likelihood:                 354.14
# No. Observations:                 1994   AIC:                            -702.3
# Df Residuals:                     1991   BIC:                            -685.5
# Df Model:                            2
# Covariance Type:             nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.1499      0.006     25.594      0.000       0.138       0.161
# ...

# %%
fitd = smf.ols(formula='ViolentCrimesPerPop ~  HousVacant', data=data).fit()
print(fitd.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.178
# Model:                             OLS   Adj. R-squared:                  0.177
# Method:                  Least Squares   F-statistic:                     430.1
# Date:                 Sun, 18 Feb 2024   Prob (F-statistic):           1.16e-86
# Time:                         11:27:28   Log-Likelihood:                 270.87
# No. Observations:                 1994   AIC:                            -537.7
# Df Residuals:                     1992   BIC:                            -526.5
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1879      0.005     35.350      0.000       0.177       0.198
# ...
